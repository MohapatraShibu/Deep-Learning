# %% [markdown]
# ## **Practical No: 6**
#
# ### **AIM:** Build a recommendation engine Boltzmann machines for the entertainment sector.

# %% [markdown]
# ### **CODE and OUTPUT**

# %%
'''Main'''
import numpy as np
import pandas as pd
import os, time, re
import pickle, gzip, datetime
from datetime import datetime

'''Data Viz'''
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
import matplotlib as mpl

# %matplotlib inline

'''Data Prep and Model Evaluation'''
from sklearn import preprocessing as pp
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import StratifiedKFold 
from sklearn.metrics import log_loss
from sklearn.metrics import precision_recall_curve, average_precision_score
from sklearn.metrics import roc_curve, auc, roc_auc_score, mean_squared_error

'''Algos'''
import lightgbm as lgb

'''TensorFlow and Keras'''
import tensorflow as tf
import keras
from keras import backend as K
from keras.models import Sequential, Model
from keras.layers import Activation, Dense, Dropout
from keras.layers import BatchNormalization, Input, Lambda
from keras.layers import Embedding, Flatten, dot
from keras import regularizers
from keras.losses import mse, binary_crossentropy

# %%
# Load the data
ratingDF = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Dataset/rating.csv")

# %%
# Convert fields into appropriate data types
ratingDF.userId = ratingDF.userId.astype(str).astype(int)
ratingDF.movieId = ratingDF.movieId.astype(str).astype(int)
ratingDF.rating = ratingDF.rating.astype(str).astype(float)
ratingDF.timestamp = pd.to_datetime(ratingDF.timestamp)

# %%
# Preview data
ratingDF.head()
# Out:
#    userId  movieId  rating           timestamp
# 0       1        2     3.5 2005-04-02 23:53:47
# 1       1       29     3.5 2005-04-02 23:31:16
# 2       1       32     3.5 2005-04-02 23:33:39
# 3       1       47     3.5 2005-04-02 23:32:07
# 4       1       50     3.5 2005-04-02 23:29:40

# %%
# Calculate summary statistics on full dataset

# 20,000,263 ratings
# 26,744 unique movies
# 138,493 unique users
# 144 ratings on average per user

n_users = ratingDF.userId.unique().shape[0]
n_movies = ratingDF.movieId.unique().shape[0]
n_ratings = len(ratingDF)
avg_ratings_per_user = n_ratings/n_users

print('Number of unique users: ', n_users)
print('Number of unique movies: ', n_movies)
print('Number of total ratings: ', n_ratings)
print('Average number of ratings per user: ', avg_ratings_per_user)
# Out:
# Number of unique users:  138493
# Number of unique movies:  26744
# Number of total ratings:  20000263
# Average number of ratings per user:  144.4135299257002

# %%
# Reduce size of dataset by taking top 1000 movies
movieIndex = ratingDF.groupby("movieId").count().sort_values(by= \
                "rating",ascending=False)[0:1000].index
ratingDFX2 = ratingDF[ratingDF.movieId.isin(movieIndex)]
ratingDFX2.count()
# Out:
# userId       12840344
# movieId      12840344
# rating       12840344
# timestamp    12840344
# dtype: int64

# %%
# Reduce size of dataset by sampling 1000 users
userIndex = ratingDFX2.groupby("userId").count().sort_values(by= \
    "rating",ascending=False).sample(n=1000, random_state=2018).index
ratingDFX3 = ratingDFX2[ratingDFX2.userId.isin(userIndex)]
ratingDFX3.count()
# Out:
# userId       90213
# movieId      90213
# rating       90213
# timestamp    90213
# dtype: int64

# %%
# Reindex movie ID
movies = ratingDFX3.movieId.unique()
moviesDF = pd.DataFrame(data=movies,columns=['originalMovieId'])
moviesDF['newMovieId'] = moviesDF.index+1
moviesDF.head()
# Out:
#    originalMovieId  newMovieId
# 0               50           1
# 1              163           2
# 2              216           3
# 3              296           4
# 4              333           5

# %%
# Reindex user ID
users = ratingDFX3.userId.unique()
usersDF = pd.DataFrame(data=users,columns=['originalUserId'])
usersDF['newUserId'] = usersDF.index+1
usersDF.head()
# Out:
#    originalUserId  newUserId
# 0              49          1
# 1             260          2
# 2             311          3
# 3             319          4
# 4             499          5

# %%
# Generate newly merged DataFrame
ratingDFX3 = ratingDFX3.merge(moviesDF,left_on='movieId', \
                              right_on='originalMovieId')
ratingDFX3.drop(labels='originalMovieId', axis=1, inplace=True)

ratingDFX3 = ratingDFX3.merge(usersDF,left_on='userId', \
                              right_on='originalUserId')
ratingDFX3.drop(labels='originalUserId', axis=1, inplace=True)
ratingDFX3.head()
# Out:
#    userId  movieId  rating           timestamp  newMovieId  newUserId
# 0      49       50     5.0 2013-05-03 02:50:26           1          1
# 1      49      163     3.5 2013-05-03 02:43:37           2          1
# 2      49      216     3.0 2013-05-03 02:45:58           3          1
# 3      49      296     5.0 2013-05-03 02:50:13           4          1
# 4      49      333     3.0 2013-05-03 02:44:38           5          1

# %%
# Calculate summary statistics on reduced dataset
n_users = ratingDFX3.userId.unique().shape[0]
n_movies = ratingDFX3.movieId.unique().shape[0]
n_ratings = len(ratingDFX3)
avg_ratings_per_user = n_ratings/n_users

print('Number of unique users: ', n_users)
print('Number of unique movies: ', n_movies)
print('Number of total ratings: ', n_ratings)
print('Average number of ratings per user: ', avg_ratings_per_user)
# Out:
# Number of unique users:  1000
# Number of unique movies:  1000
# Number of total ratings:  90213
# Average number of ratings per user:  90.213

# %%
# Split into validation and test, such that each is 5% of the dataset
X_train, X_test = train_test_split(ratingDFX3, test_size=0.10, \
                                   shuffle=True, random_state=2018)

X_validation, X_test = train_test_split(X_test, test_size=0.50, \
                                        shuffle=True, random_state=2018)

# %%
# Confirm size of train, validation, and test datasets
print('Size of train set: ', len(X_train))
print('Size of validation set: ', len(X_validation))
print('Size of test set: ', len(X_test))
# Out:
# Size of train set:  81191
# Size of validation set:  4511
# Size of test set:  4511

# %%
# Generate ratings matrix for train
ratings_train = np.zeros((n_users, n_movies))
for row in X_train.itertuples():
    ratings_train[row[6]-1, row[5]-1] = row[3]

# %%
ratings_train.shape
# Out:
# (1000, 1000)

# %%
# Calculate sparsity of the train ratings matrix
sparsity = float(len(ratings_train.nonzero()[0]))
sparsity /= (ratings_train.shape[0] * ratings_train.shape[1])
sparsity *= 100
print('Sparsity: {:4.2f}%'.format(sparsity))
# Out:
# Sparsity: 8.12%

# %%
# Generate ratings matrix for validation
ratings_validation = np.zeros((n_users, n_movies))
for row in X_validation.itertuples():
    ratings_validation[row[6]-1, row[5]-1] = row[3]

# %%
# Generate ratings matrix for test
ratings_test = np.zeros((n_users, n_movies))
for row in X_test.itertuples():
    ratings_test[row[6]-1, row[5]-1] = row[3]

# %%
# Calculate sparsity of the validation ratings matrix
sparsity = float(len(ratings_validation.nonzero()[0]))
sparsity /= (ratings_validation.shape[0] * ratings_validation.shape[1])
sparsity *= 100
print('Sparsity: {:4.2f}%'.format(sparsity))
# Out:
# Sparsity: 0.45%

# %%
# Experiment one - Assign naive 3.5 rating and calculate baseline MSE

actual_validation = ratings_validation[ratings_validation.nonzero()].flatten()

pred_validation = np.zeros((len(X_validation),1))
pred_validation[pred_validation==0] = 3.5

naive_prediction = mean_squared_error(pred_validation, actual_validation)
print('Mean squared error using naive prediction:', naive_prediction)
# Out:
# Mean squared error using naive prediction: 1.055420084238528

# %%
# Experiment two - Predict a user's rating based on user's average rating 
# for all other movies

ratings_validation_prediction = np.zeros((n_users, n_movies))
i = 0
for row in ratings_train:
    ratings_validation_prediction[i][ratings_validation_prediction[i]==0] \
        = np.mean(row[row>0])
    i += 1

pred_validation = ratings_validation_prediction \
    [ratings_validation.nonzero()].flatten()
user_average = mean_squared_error(pred_validation, actual_validation)
print('Mean squared error using user average:', user_average)
# Out:
# Mean squared error using user average: 0.9090717929472647

# %%
# Experiment three - Predict a user's rating for a movie based on the
# average rating other users have given that movie

ratings_validation_prediction = np.zeros((n_users, n_movies)).T
i = 0
for row in ratings_train.T:
    ratings_validation_prediction[i][ratings_validation_prediction[i]==0] \
        = np.mean(row[row>0])
    i += 1

ratings_validation_prediction = ratings_validation_prediction.T
pred_validation = ratings_validation_prediction \
    [ratings_validation.nonzero()].flatten()
movie_average = mean_squared_error(pred_validation, actual_validation)
print('Mean squared error using movie average:', movie_average)
# Out:
# Mean squared error using movie average: 0.9136057106858655

# %%
# Experiment four - Recommender System using Matrix Factorization
# 1 Latent Factor

n_latent_factors = 1

user_input = Input(shape=[1], name='user')
user_embedding = Embedding(input_dim=n_users + 1, \
                           output_dim=n_latent_factors, \
                           name='user_embedding')(user_input)
user_vec = Flatten(name='flatten_users')(user_embedding)

movie_input = Input(shape=[1], name='movie')
movie_embedding = Embedding(input_dim=n_movies + 1, \
                            output_dim=n_latent_factors,
                            name='movie_embedding')(movie_input)
movie_vec = Flatten(name='flatten_movies')(movie_embedding)

product = dot([movie_vec, user_vec], axes=1)
model = Model(inputs=[user_input, movie_input], outputs=product)
model.compile('adam', 'mean_squared_error')

# %%
history = model.fit(x=[X_train.newUserId, X_train.newMovieId], \
                    y=X_train.rating, epochs=100, \
                    validation_data=([X_validation.newUserId, \
                    X_validation.newMovieId], X_validation.rating), \
                    verbose=1)
# Out:
# Epoch 1/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 13.3814 - val_loss: 11.4075
# Epoch 2/100
# 2538/2538 [==============================] - 7s 3ms/step - loss: 8.6914 - val_loss: 6.1696
# Epoch 3/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 4.4006 - val_loss: 3.2031
# Epoch 4/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 2.4570 - val_loss: 1.9912
# Epoch 5/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 1.6014 - val_loss: 1.4118
# Epoch 6/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 1.1761 - val_loss: 1.1216
# Epoch 7/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.9613 - val_loss: 0.9695
# Epoch 8/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.8514 - val_loss: 0.8913
# Epoch 9/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7941 - val_loss: 0.8489
# Epoch 10/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7640 - val_loss: 0.8256
# Epoch 11/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7481 - val_loss: 0.8134
# Epoch 12/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7394 - val_loss: 0.8063
# Epoch 13/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7345 - val_loss: 0.8036
# Epoch 14/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7318 - val_loss: 0.8017
# Epoch 15/100
# 2538/2538 [==============================] - 7s 3ms/step - loss: 0.7304 - val_loss: 0.7997
# Epoch 16/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7293 - val_loss: 0.8001
# Epoch 17/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7287 - val_loss: 0.8009
# Epoch 18/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7285 - val_loss: 0.7992
# Epoch 19/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7282 - val_loss: 0.8001
# Epoch 20/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7281 - val_loss: 0.7986
# Epoch 21/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7281 - val_loss: 0.7988
# Epoch 22/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7281 - val_loss: 0.8001
# Epoch 23/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7279 - val_loss: 0.7980
# Epoch 24/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7279 - val_loss: 0.7983
# Epoch 25/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7278 - val_loss: 0.7987
# Epoch 26/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7278 - val_loss: 0.7989
# Epoch 27/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7278 - val_loss: 0.7986
# Epoch 28/100
# 2538/2538 [==============================] - 7s 3ms/step - loss: 0.7278 - val_loss: 0.7968
# Epoch 29/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7278 - val_loss: 0.7974
# Epoch 30/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7279 - val_loss: 0.7983
# Epoch 31/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7277 - val_loss: 0.7993
# Epoch 32/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7278 - val_loss: 0.7992
# Epoch 33/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7278 - val_loss: 0.7989
# Epoch 34/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7277 - val_loss: 0.7979
# Epoch 35/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7277 - val_loss: 0.7986
# Epoch 36/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7277 - val_loss: 0.7978
# Epoch 37/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7279 - val_loss: 0.7971
# Epoch 38/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7278 - val_loss: 0.7973
# Epoch 39/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7277 - val_loss: 0.7994
# Epoch 40/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7278 - val_loss: 0.7969
# Epoch 41/100
# 2538/2538 [==============================] - 6s 3ms/step - loss: 0.7277 - val_loss: 0.7996
# Epoch 42/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7277 - val_loss: 0.7974
# Epoch 43/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7277 - val_loss: 0.7992
# Epoch 44/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7277 - val_loss: 0.7992
# Epoch 45/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7278 - val_loss: 0.7992
# Epoch 46/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7278 - val_loss: 0.7982
# Epoch 47/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7277 - val_loss: 0.7979
# Epoch 48/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7277 - val_loss: 0.7975
# Epoch 49/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7276 - val_loss: 0.7980
# Epoch 50/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7278 - val_loss: 0.7985
# Epoch 51/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7278 - val_loss: 0.7962
# Epoch 52/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7278 - val_loss: 0.7979
# Epoch 53/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7277 - val_loss: 0.7974
# Epoch 54/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7278 - val_loss: 0.7988
# Epoch 55/100
# 2538/2538 [==============================] - 6s 3ms/step - loss: 0.7277 - val_loss: 0.7980
# Epoch 56/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7278 - val_loss: 0.7968
# Epoch 57/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7276 - val_loss: 0.7973
# Epoch 58/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7278 - val_loss: 0.7980
# Epoch 59/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7277 - val_loss: 0.7979
# Epoch 60/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7278 - val_loss: 0.7979
# Epoch 61/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7278 - val_loss: 0.7978
# Epoch 62/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7277 - val_loss: 0.7985
# Epoch 63/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7277 - val_loss: 0.7992
# Epoch 64/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7277 - val_loss: 0.7983
# Epoch 65/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7277 - val_loss: 0.7991
# Epoch 66/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7277 - val_loss: 0.7987
# Epoch 67/100
# 2538/2538 [==============================] - 7s 3ms/step - loss: 0.7278 - val_loss: 0.7991
# Epoch 68/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7278 - val_loss: 0.7981
# Epoch 69/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7276 - val_loss: 0.7980
# Epoch 70/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7278 - val_loss: 0.7985
# Epoch 71/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7277 - val_loss: 0.7978
# Epoch 72/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7277 - val_loss: 0.7980
# Epoch 73/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7277 - val_loss: 0.7978
# Epoch 74/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7278 - val_loss: 0.7964
# Epoch 75/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7277 - val_loss: 0.7988
# Epoch 76/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7277 - val_loss: 0.7978
# Epoch 77/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7277 - val_loss: 0.7974
# Epoch 78/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7278 - val_loss: 0.7976
# Epoch 79/100
# 2538/2538 [==============================] - 7s 3ms/step - loss: 0.7278 - val_loss: 0.7976
# Epoch 80/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7278 - val_loss: 0.7989
# Epoch 81/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7278 - val_loss: 0.7981
# Epoch 82/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7276 - val_loss: 0.7983
# Epoch 83/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7276 - val_loss: 0.7983
# Epoch 84/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7278 - val_loss: 0.7983
# Epoch 85/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7278 - val_loss: 0.7970
# Epoch 86/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7277 - val_loss: 0.7976
# Epoch 87/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7278 - val_loss: 0.7967
# Epoch 88/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7278 - val_loss: 0.7978
# Epoch 89/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7276 - val_loss: 0.7967
# Epoch 90/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7276 - val_loss: 0.7954
# Epoch 91/100
# 2538/2538 [==============================] - 7s 3ms/step - loss: 0.7278 - val_loss: 0.7966
# Epoch 92/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7277 - val_loss: 0.7974
# Epoch 93/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7276 - val_loss: 0.7973
# Epoch 94/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7277 - val_loss: 0.7972
# Epoch 95/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7276 - val_loss: 0.7983
# Epoch 96/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7277 - val_loss: 0.7987
# Epoch 97/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7277 - val_loss: 0.7982
# Epoch 98/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7276 - val_loss: 0.7998
# Epoch 99/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7278 - val_loss: 0.7986
# Epoch 100/100
# 2538/2538 [==============================] - 5s 2ms/step - loss: 0.7277 - val_loss: 0.7977

# %%
pd.Series(history.history['val_loss'][10:]).plot(logy=False)
plt.xlabel("Epoch")
plt.ylabel("Validation Error")
print('Minimum MSE: ', min(history.history['val_loss']))
# Out:
# Minimum MSE:  0.7954029440879822

# %%
# Experiment five - Recommender System using Matrix Factorization
# 3 Latent Factors

n_latent_factors = 3

user_input = Input(shape=[1], name='user')
user_embedding = Embedding(input_dim=n_users + 1, \
                           output_dim=n_latent_factors, \
                           embeddings_regularizer=regularizers.l1(10e-7), \
                           name='user_embedding')(user_input)
user_vec = Flatten(name='flatten_users')(user_embedding)

movie_input = Input(shape=[1], name='movie')
movie_embedding = Embedding(input_dim=n_movies + 1, \
                            output_dim=n_latent_factors, \
                            embeddings_regularizer=regularizers.l1(10e-7), \
                            name='movie_embedding')(movie_input)
movie_vec = Flatten(name='flatten_movies')(movie_embedding)

product = dot([movie_vec, user_vec], axes=1)
model = Model(inputs=[user_input, movie_input], outputs=product)
model.compile('adam', 'mean_squared_error')

# %%
history = model.fit(x=[X_train.newUserId, X_train.newMovieId], \
                    y=X_train.rating, epochs=100, \
                    validation_data=([X_validation.newUserId, \
                    X_validation.newMovieId], X_validation.rating), \
                    verbose=1)
# Out:
# Epoch 1/100
# 2538/2538 [==============================] - 7s 2ms/step - loss: 11.8470 - val_loss: 7.3148
# Epoch 2/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 4.1904 - val_loss: 2.4498
# Epoch 3/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 1.7305 - val_loss: 1.3423
# Epoch 4/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 1.0686 - val_loss: 0.9897
# Epoch 5/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.8541 - val_loss: 0.8728
# Epoch 6/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7826 - val_loss: 0.8291
# Epoch 7/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7575 - val_loss: 0.8149
# Epoch 8/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7487 - val_loss: 0.8127
# Epoch 9/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7453 - val_loss: 0.8096
# Epoch 10/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7440 - val_loss: 0.8081
# Epoch 11/100
# 2538/2538 [==============================] - 8s 3ms/step - loss: 0.7432 - val_loss: 0.8061
# Epoch 12/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7427 - val_loss: 0.8073
# Epoch 13/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7423 - val_loss: 0.8050
# Epoch 14/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7423 - val_loss: 0.8073
# Epoch 15/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7424 - val_loss: 0.8071
# Epoch 16/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7420 - val_loss: 0.8084
# Epoch 17/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7418 - val_loss: 0.8084
# Epoch 18/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7416 - val_loss: 0.8075
# Epoch 19/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7415 - val_loss: 0.8065
# Epoch 20/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7408 - val_loss: 0.8052
# Epoch 21/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7403 - val_loss: 0.8055
# Epoch 22/100
# 2538/2538 [==============================] - 7s 3ms/step - loss: 0.7396 - val_loss: 0.8069
# Epoch 23/100
# 2538/2538 [==============================] - 7s 3ms/step - loss: 0.7390 - val_loss: 0.8055
# Epoch 24/100
# 2538/2538 [==============================] - 7s 3ms/step - loss: 0.7379 - val_loss: 0.8055
# Epoch 25/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7368 - val_loss: 0.8034
# Epoch 26/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7357 - val_loss: 0.8056
# Epoch 27/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7341 - val_loss: 0.8005
# Epoch 28/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7316 - val_loss: 0.8014
# Epoch 29/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7292 - val_loss: 0.7971
# Epoch 30/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7266 - val_loss: 0.7970
# Epoch 31/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7231 - val_loss: 0.7941
# Epoch 32/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7190 - val_loss: 0.7942
# Epoch 33/100
# 2538/2538 [==============================] - 8s 3ms/step - loss: 0.7152 - val_loss: 0.7935
# Epoch 34/100
# 2538/2538 [==============================] - 7s 3ms/step - loss: 0.7110 - val_loss: 0.7898
# Epoch 35/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7065 - val_loss: 0.7856
# Epoch 36/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7021 - val_loss: 0.7865
# Epoch 37/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6980 - val_loss: 0.7824
# Epoch 38/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6939 - val_loss: 0.7806
# Epoch 39/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6904 - val_loss: 0.7763
# Epoch 40/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6867 - val_loss: 0.7793
# Epoch 41/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6834 - val_loss: 0.7776
# Epoch 42/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6803 - val_loss: 0.7760
# Epoch 43/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6776 - val_loss: 0.7775
# Epoch 44/100
# 2538/2538 [==============================] - 7s 3ms/step - loss: 0.6747 - val_loss: 0.7751
# Epoch 45/100
# 2538/2538 [==============================] - 7s 3ms/step - loss: 0.6716 - val_loss: 0.7773
# Epoch 46/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6693 - val_loss: 0.7746
# Epoch 47/100
# 2538/2538 [==============================] - 8s 3ms/step - loss: 0.6665 - val_loss: 0.7730
# Epoch 48/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6644 - val_loss: 0.7743
# Epoch 49/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6620 - val_loss: 0.7745
# Epoch 50/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6598 - val_loss: 0.7754
# Epoch 51/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6576 - val_loss: 0.7733
# Epoch 52/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6556 - val_loss: 0.7736
# Epoch 53/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6534 - val_loss: 0.7739
# Epoch 54/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6517 - val_loss: 0.7748
# Epoch 55/100
# 2538/2538 [==============================] - 7s 3ms/step - loss: 0.6500 - val_loss: 0.7752
# Epoch 56/100
# 2538/2538 [==============================] - 7s 3ms/step - loss: 0.6484 - val_loss: 0.7745
# Epoch 57/100
# 2538/2538 [==============================] - 7s 3ms/step - loss: 0.6470 - val_loss: 0.7754
# Epoch 58/100
# 2538/2538 [==============================] - 8s 3ms/step - loss: 0.6457 - val_loss: 0.7769
# Epoch 59/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6447 - val_loss: 0.7805
# Epoch 60/100
# 2538/2538 [==============================] - 7s 3ms/step - loss: 0.6432 - val_loss: 0.7779
# Epoch 61/100
# 2538/2538 [==============================] - 6s 3ms/step - loss: 0.6419 - val_loss: 0.7777
# Epoch 62/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6409 - val_loss: 0.7812
# Epoch 63/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6399 - val_loss: 0.7776
# Epoch 64/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6390 - val_loss: 0.7817
# Epoch 65/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6382 - val_loss: 0.7802
# Epoch 66/100
# 2538/2538 [==============================] - 8s 3ms/step - loss: 0.6374 - val_loss: 0.7801
# Epoch 67/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6364 - val_loss: 0.7845
# Epoch 68/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6358 - val_loss: 0.7810
# Epoch 69/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6352 - val_loss: 0.7823
# Epoch 70/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6343 - val_loss: 0.7842
# Epoch 71/100
# 2538/2538 [==============================] - 6s 3ms/step - loss: 0.6335 - val_loss: 0.7832
# Epoch 72/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6333 - val_loss: 0.7846
# Epoch 73/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6325 - val_loss: 0.7845
# Epoch 74/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6320 - val_loss: 0.7862
# Epoch 75/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6318 - val_loss: 0.7854
# Epoch 76/100
# 2538/2538 [==============================] - 7s 3ms/step - loss: 0.6311 - val_loss: 0.7877
# Epoch 77/100
# 2538/2538 [==============================] - 7s 3ms/step - loss: 0.6305 - val_loss: 0.7849
# Epoch 78/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6298 - val_loss: 0.7861
# Epoch 79/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6298 - val_loss: 0.7863
# Epoch 80/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6293 - val_loss: 0.7886
# Epoch 81/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6288 - val_loss: 0.7882
# Epoch 82/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6286 - val_loss: 0.7864
# Epoch 83/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6280 - val_loss: 0.7890
# Epoch 84/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6277 - val_loss: 0.7913
# Epoch 85/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6275 - val_loss: 0.7902
# Epoch 86/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6273 - val_loss: 0.7901
# Epoch 87/100
# 2538/2538 [==============================] - 8s 3ms/step - loss: 0.6270 - val_loss: 0.7904
# Epoch 88/100
# 2538/2538 [==============================] - 6s 3ms/step - loss: 0.6267 - val_loss: 0.7893
# Epoch 89/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6263 - val_loss: 0.7899
# Epoch 90/100
# 2538/2538 [==============================] - 7s 3ms/step - loss: 0.6259 - val_loss: 0.7896
# Epoch 91/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6259 - val_loss: 0.7913
# Epoch 92/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6255 - val_loss: 0.7899
# Epoch 93/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6254 - val_loss: 0.7906
# Epoch 94/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6250 - val_loss: 0.7932
# Epoch 95/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6249 - val_loss: 0.7937
# Epoch 96/100
# 2538/2538 [==============================] - 7s 3ms/step - loss: 0.6246 - val_loss: 0.7936
# Epoch 97/100
# 2538/2538 [==============================] - 6s 3ms/step - loss: 0.6245 - val_loss: 0.7900
# Epoch 98/100
# 2538/2538 [==============================] - 9s 3ms/step - loss: 0.6243 - val_loss: 0.7914
# Epoch 99/100
# 2538/2538 [==============================] - 8s 3ms/step - loss: 0.6240 - val_loss: 0.7940
# Epoch 100/100
# 2538/2538 [==============================] - 6s 3ms/step - loss: 0.6238 - val_loss: 0.7928

# %%
pd.Series(history.history['val_loss'][10:]).plot(logy=False)
plt.xlabel("Epoch")
plt.ylabel("Validation Error")
print('Minimum MSE: ', min(history.history['val_loss']))
# Out:
# Minimum MSE:  0.773015558719635

# %%
# Experiment six - Recommender System using Matrix Factorization
# 5 Latent Factors

n_latent_factors = 5

user_input = Input(shape=[1], name='user')
user_embedding = Embedding(input_dim=n_users + 1, \
                           output_dim=n_latent_factors, \
                           embeddings_regularizer=regularizers.l1(10e-7), \
                           name='user_embedding')(user_input)
user_vec = Flatten(name='flatten_users')(user_embedding)

movie_input = Input(shape=[1], name='movie')
movie_embedding = Embedding(input_dim=n_movies + 1, \
                            output_dim=n_latent_factors, \
                            embeddings_regularizer=regularizers.l1(10e-7), \
                            name='movie_embedding')(movie_input)
movie_vec = Flatten(name='flatten_movies')(movie_embedding)

product = dot([movie_vec, user_vec], axes=1)
model = Model(inputs=[user_input, movie_input], outputs=product)
model.compile('adam', 'mean_squared_error')

# %%
history = model.fit(x=[X_train.newUserId, X_train.newMovieId], \
                    y=X_train.rating, epochs=100, \
                    validation_data=([X_validation.newUserId, \
                    X_validation.newMovieId], X_validation.rating), \
                    verbose=1)
# Out:
# Epoch 1/100
# 2538/2538 [==============================] - 9s 3ms/step - loss: 10.8360 - val_loss: 5.1245
# Epoch 2/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 2.7953 - val_loss: 1.6655
# Epoch 3/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 1.2109 - val_loss: 1.0290
# Epoch 4/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.8681 - val_loss: 0.8664
# Epoch 5/100
# 2538/2538 [==============================] - 7s 3ms/step - loss: 0.7818 - val_loss: 0.8252
# Epoch 6/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7593 - val_loss: 0.8151
# Epoch 7/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7524 - val_loss: 0.8163
# Epoch 8/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7505 - val_loss: 0.8162
# Epoch 9/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7499 - val_loss: 0.8121
# Epoch 10/100
# 2538/2538 [==============================] - 7s 3ms/step - loss: 0.7486 - val_loss: 0.8090
# Epoch 11/100
# 2538/2538 [==============================] - 7s 3ms/step - loss: 0.7488 - val_loss: 0.8105
# Epoch 12/100
# 2538/2538 [==============================] - 7s 3ms/step - loss: 0.7485 - val_loss: 0.8115
# Epoch 13/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7480 - val_loss: 0.8098
# Epoch 14/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7477 - val_loss: 0.8113
# Epoch 15/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7464 - val_loss: 0.8105
# Epoch 16/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7450 - val_loss: 0.8077
# Epoch 17/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7440 - val_loss: 0.8134
# Epoch 18/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7420 - val_loss: 0.8096
# Epoch 19/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7401 - val_loss: 0.8031
# Epoch 20/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7366 - val_loss: 0.8055
# Epoch 21/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7335 - val_loss: 0.7994
# Epoch 22/100
# 2538/2538 [==============================] - 7s 3ms/step - loss: 0.7287 - val_loss: 0.7966
# Epoch 23/100
# 2538/2538 [==============================] - 7s 3ms/step - loss: 0.7238 - val_loss: 0.7962
# Epoch 24/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7175 - val_loss: 0.7878
# Epoch 25/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7106 - val_loss: 0.7865
# Epoch 26/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.7035 - val_loss: 0.7846
# Epoch 27/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6961 - val_loss: 0.7794
# Epoch 28/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6894 - val_loss: 0.7800
# Epoch 29/100
# 2538/2538 [==============================] - 7s 3ms/step - loss: 0.6822 - val_loss: 0.7752
# Epoch 30/100
# 2538/2538 [==============================] - 6s 3ms/step - loss: 0.6754 - val_loss: 0.7768
# Epoch 31/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6693 - val_loss: 0.7744
# Epoch 32/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6627 - val_loss: 0.7713
# Epoch 33/100
# 2538/2538 [==============================] - 7s 3ms/step - loss: 0.6568 - val_loss: 0.7712
# Epoch 34/100
# 2538/2538 [==============================] - 7s 3ms/step - loss: 0.6502 - val_loss: 0.7684
# Epoch 35/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6444 - val_loss: 0.7681
# Epoch 36/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6389 - val_loss: 0.7697
# Epoch 37/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6337 - val_loss: 0.7649
# Epoch 38/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6284 - val_loss: 0.7633
# Epoch 39/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6236 - val_loss: 0.7639
# Epoch 40/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6193 - val_loss: 0.7655
# Epoch 41/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6151 - val_loss: 0.7663
# Epoch 42/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6110 - val_loss: 0.7676
# Epoch 43/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6077 - val_loss: 0.7702
# Epoch 44/100
# 2538/2538 [==============================] - 8s 3ms/step - loss: 0.6042 - val_loss: 0.7693
# Epoch 45/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.6015 - val_loss: 0.7728
# Epoch 46/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5985 - val_loss: 0.7694
# Epoch 47/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5958 - val_loss: 0.7717
# Epoch 48/100
# 2538/2538 [==============================] - 6s 3ms/step - loss: 0.5937 - val_loss: 0.7716
# Epoch 49/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5913 - val_loss: 0.7739
# Epoch 50/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5892 - val_loss: 0.7736
# Epoch 51/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5873 - val_loss: 0.7743
# Epoch 52/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5858 - val_loss: 0.7780
# Epoch 53/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5842 - val_loss: 0.7787
# Epoch 54/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5823 - val_loss: 0.7802
# Epoch 55/100
# 2538/2538 [==============================] - 8s 3ms/step - loss: 0.5807 - val_loss: 0.7806
# Epoch 56/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5792 - val_loss: 0.7830
# Epoch 57/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5778 - val_loss: 0.7843
# Epoch 58/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5770 - val_loss: 0.7837
# Epoch 59/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5757 - val_loss: 0.7840
# Epoch 60/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5745 - val_loss: 0.7872
# Epoch 61/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5733 - val_loss: 0.7861
# Epoch 62/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5727 - val_loss: 0.7894
# Epoch 63/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5714 - val_loss: 0.7927
# Epoch 64/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5708 - val_loss: 0.7932
# Epoch 65/100
# 2538/2538 [==============================] - 7s 3ms/step - loss: 0.5696 - val_loss: 0.7882
# Epoch 66/100
# 2538/2538 [==============================] - 8s 3ms/step - loss: 0.5690 - val_loss: 0.7937
# Epoch 67/100
# 2538/2538 [==============================] - 7s 3ms/step - loss: 0.5682 - val_loss: 0.7937
# Epoch 68/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5673 - val_loss: 0.7908
# Epoch 69/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5666 - val_loss: 0.7966
# Epoch 70/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5662 - val_loss: 0.7941
# Epoch 71/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5652 - val_loss: 0.7950
# Epoch 72/100
# 2538/2538 [==============================] - 6s 3ms/step - loss: 0.5648 - val_loss: 0.7946
# Epoch 73/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5645 - val_loss: 0.7958
# Epoch 74/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5637 - val_loss: 0.7995
# Epoch 75/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5630 - val_loss: 0.8001
# Epoch 76/100
# 2538/2538 [==============================] - 9s 3ms/step - loss: 0.5623 - val_loss: 0.7991
# Epoch 77/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5620 - val_loss: 0.7988
# Epoch 78/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5615 - val_loss: 0.8042
# Epoch 79/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5613 - val_loss: 0.8000
# Epoch 80/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5605 - val_loss: 0.8035
# Epoch 81/100
# 2538/2538 [==============================] - 7s 3ms/step - loss: 0.5602 - val_loss: 0.8042
# Epoch 82/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5593 - val_loss: 0.8039
# Epoch 83/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5593 - val_loss: 0.8018
# Epoch 84/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5591 - val_loss: 0.8019
# Epoch 85/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5585 - val_loss: 0.8072
# Epoch 86/100
# 2538/2538 [==============================] - 7s 3ms/step - loss: 0.5580 - val_loss: 0.8109
# Epoch 87/100
# 2538/2538 [==============================] - 7s 3ms/step - loss: 0.5580 - val_loss: 0.8076
# Epoch 88/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5576 - val_loss: 0.8084
# Epoch 89/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5571 - val_loss: 0.8070
# Epoch 90/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5567 - val_loss: 0.8094
# Epoch 91/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5567 - val_loss: 0.8099
# Epoch 92/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5564 - val_loss: 0.8084
# Epoch 93/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5557 - val_loss: 0.8123
# Epoch 94/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5555 - val_loss: 0.8121
# Epoch 95/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5555 - val_loss: 0.8121
# Epoch 96/100
# 2538/2538 [==============================] - 6s 3ms/step - loss: 0.5551 - val_loss: 0.8146
# Epoch 97/100
# 2538/2538 [==============================] - 8s 3ms/step - loss: 0.5549 - val_loss: 0.8123
# Epoch 98/100
# 2538/2538 [==============================] - 6s 3ms/step - loss: 0.5545 - val_loss: 0.8136
# Epoch 99/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5544 - val_loss: 0.8157
# Epoch 100/100
# 2538/2538 [==============================] - 6s 2ms/step - loss: 0.5540 - val_loss: 0.8180

# %%
pd.Series(history.history['val_loss'][10:]).plot(logy=False)
plt.xlabel("Epoch")
plt.ylabel("Validation Error")
print('Minimum MSE: ', min(history.history['val_loss']))
# Out:
# Minimum MSE:  0.7632550597190857

# %%
# Experiment seven - Recommender System using RBMs

# Define RBM class
class RBM(object):
    
    def __init__(self, input_size, output_size, 
                 learning_rate, epochs, batchsize):
        # Define hyperparameters
        self._input_size = input_size
        self._output_size = output_size
        self.learning_rate = learning_rate
        self.epochs = epochs
        self.batchsize = batchsize
        
        # Initialize weights and biases using zero matrices
        self.w = np.zeros([input_size, output_size], dtype=np.float32)
        self.hb = np.zeros([output_size], dtype=np.float32)
        self.vb = np.zeros([input_size], dtype=np.float32)

    def prob_h_given_v(self, visible, w, hb):
        return tf.nn.sigmoid(tf.matmul(visible, w) + hb)

    def prob_v_given_h(self, hidden, w, vb):
        return tf.nn.sigmoid(tf.matmul(hidden, tf.transpose(w)) + vb)
    
    def sample_prob(self, probs):
        return tf.nn.relu(tf.sign(probs - tf.random_uniform(tf.shape(probs))))

    def train(self, X):
        _w = tf.placeholder(tf.float32, [self._input_size, self._output_size])
        _hb = tf.placeholder(tf.float32, [self._output_size])
        _vb = tf.placeholder(tf.float32, [self._input_size])
        
        prv_w = np.zeros([self._input_size, self._output_size], dtype=np.float32)
        prv_hb = np.zeros([self._output_size], dtype=np.float32)
        prv_vb = np.zeros([self._input_size], dtype=np.float32)
        
        cur_w = np.zeros([self._input_size, self._output_size], dtype=np.float32)
        cur_hb = np.zeros([self._output_size], dtype=np.float32)
        cur_vb = np.zeros([self._input_size], dtype=np.float32)
        
        v0 = tf.placeholder(tf.float32, [None, self._input_size])
        h0 = self.sample_prob(self.prob_h_given_v(v0, _w, _hb))
        v1 = self.sample_prob(self.prob_v_given_h(h0, _w, _vb))
        h1 = self.prob_h_given_v(v1, _w, _hb)
        
        positive_grad = tf.matmul(tf.transpose(v0), h0)
        negative_grad = tf.matmul(tf.transpose(v1), h1)
        
        update_w = _w + self.learning_rate * \
            (positive_grad - negative_grad) / tf.to_float(tf.shape(v0)[0])
        update_vb = _vb +  self.learning_rate * tf.reduce_mean(v0 - v1, 0)
        update_hb = _hb +  self.learning_rate * tf.reduce_mean(h0 - h1, 0)
        
        err = tf.reduce_mean(tf.square(v0 - v1))
        
        error_list = []
        
        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())
            
            for epoch in range(self.epochs):
                for start, end in zip(range(0, len(X), \
                        self.batchsize),range(self.batchsize,len(X), \
                                              self.batchsize)):
                    batch = X[start:end]
                    cur_w = sess.run(update_w, feed_dict={v0: batch, \
                                    _w: prv_w, _hb: prv_hb, _vb: prv_vb})
                    cur_hb = sess.run(update_hb, feed_dict={v0: batch, \
                                    _w: prv_w, _hb: prv_hb, _vb: prv_vb})
                    cur_vb = sess.run(update_vb, feed_dict={v0: batch, \
                                    _w: prv_w, _hb: prv_hb, _vb: prv_vb})
                    prv_w = cur_w
                    prv_hb = cur_hb
                    prv_vb = cur_vb
                error = sess.run(err, feed_dict={v0: X, \
                                _w: cur_w, _vb: cur_vb, _hb: cur_hb})
                print ('Epoch: %d' % epoch,'reconstruction error: %f' % error)
                error_list.append(error)
            self.w = prv_w
            self.hb = prv_hb
            self.vb = prv_vb
            return error_list

    def rbm_output(self, X):
        
        input_X = tf.constant(X)
        _w = tf.constant(self.w)
        _hb = tf.constant(self.hb)
        _vb = tf.constant(self.vb)
        out = tf.nn.sigmoid(tf.matmul(input_X, _w) + _hb)
        hiddenGen = self.sample_prob(self.prob_h_given_v(input_X, _w, _hb))
        visibleGen = self.sample_prob(self.prob_v_given_h(hiddenGen, _w, _vb))
        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())
            return sess.run(out), sess.run(visibleGen), sess.run(hiddenGen)

# %%
# Begin the training cycle

# Convert inputX into float32
inputX = ratings_train
inputX = inputX.astype(np.float32)

# Define the parameters of the RBMs we will train
rbm=RBM(1000,1000,1,1000,200)

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
# Train RBM model
err = rbm.train(inputX)
outputX, reconstructedX, hiddenX = rbm.rbm_output(inputX)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# Epoch: 0 reconstruction error: 1.105672
# Epoch: 1 reconstruction error: 1.086300
# Epoch: 2 reconstruction error: 1.088289
# Epoch: 3 reconstruction error: 1.091463
# Epoch: 4 reconstruction error: 1.094885
# Epoch: 5 reconstruction error: 1.089568
# Epoch: 6 reconstruction error: 1.087010
# Epoch: 7 reconstruction error: 1.084026
# Epoch: 8 reconstruction error: 1.090812
# Epoch: 9 reconstruction error: 1.090773
# Epoch: 10 reconstruction error: 1.087659
# Epoch: 11 reconstruction error: 1.088191
# Epoch: 12 reconstruction error: 1.090932
# Epoch: 13 reconstruction error: 1.092173
# Epoch: 14 reconstruction error: 1.086355
# Epoch: 15 reconstruction error: 1.098410
# Epoch: 16 reconstruction error: 1.083730
# Epoch: 17 reconstruction error: 1.098915
# Epoch: 18 reconstruction error: 1.090055
# Epoch: 19 reconstruction error: 1.092463
# Epoch: 20 reconstruction error: 1.092366
# Epoch: 21 reconstruction error: 1.093835
# Epoch: 22 reconstruction error: 1.094741
# Epoch: 23 reconstruction error: 1.095029
# Epoch: 24 reconstruction error: 1.095976
# Epoch: 25 reconstruction error: 1.096789
# Epoch: 26 reconstruction error: 1.100886
# Epoch: 27 reconstruction error: 1.093495
# Epoch: 28 reconstruction error: 1.099002
# Epoch: 29 reconstruction error: 1.096056
# Epoch: 30 reconstruction error: 1.096917
# Epoch: 31 reconstruction error: 1.095006
# Epoch: 32 reconstruction error: 1.100674
# Epoch: 33 reconstruction error: 1.095984
# Epoch: 34 reconstruction error: 1.095665
# Epoch: 35 reconstruction error: 1.098083
# Epoch: 36 reconstruction error: 1.097880
# Epoch: 37 reconstruction error: 1.098124
# Epoch: 38 reconstruction error: 1.098317
# Epoch: 39 reconstruction error: 1.099210
# Epoch: 40 reconstruction error: 1.097978
# Epoch: 41 reconstruction error: 1.098662
# Epoch: 42 reconstruction error: 1.099694
# Epoch: 43 reconstruction error: 1.098238
# Epoch: 44 reconstruction error: 1.095999
# Epoch: 45 reconstruction error: 1.098714
# Epoch: 46 reconstruction error: 1.097234
# Epoch: 47 reconstruction error: 1.095644
# Epoch: 48 reconstruction error: 1.097388
# Epoch: 49 reconstruction error: 1.096153
# Epoch: 50 reconstruction error: 1.097136
# Epoch: 51 reconstruction error: 1.097028
# Epoch: 52 reconstruction error: 1.098312
# Epoch: 53 reconstruction error: 1.096411
# Epoch: 54 reconstruction error: 1.098529
# Epoch: 55 reconstruction error: 1.096655
# Epoch: 56 reconstruction error: 1.096912
# Epoch: 57 reconstruction error: 1.099314
# Epoch: 58 reconstruction error: 1.093940
# Epoch: 59 reconstruction error: 1.095122
# Epoch: 60 reconstruction error: 1.096774
# Epoch: 61 reconstruction error: 1.094205
# Epoch: 62 reconstruction error: 1.098389
# Epoch: 63 reconstruction error: 1.096763
# Epoch: 64 reconstruction error: 1.095870
# Epoch: 65 reconstruction error: 1.096889
# Epoch: 66 reconstruction error: 1.096820
# Epoch: 67 reconstruction error: 1.093649
# Epoch: 68 reconstruction error: 1.095168
# Epoch: 69 reconstruction error: 1.095129
# Epoch: 70 reconstruction error: 1.096768
# Epoch: 71 reconstruction error: 1.094540
# Epoch: 72 reconstruction error: 1.096493
# Epoch: 73 reconstruction error: 1.094033
# Epoch: 74 reconstruction error: 1.095001
# Epoch: 75 reconstruction error: 1.096902
# Epoch: 76 reconstruction error: 1.096290
# Epoch: 77 reconstruction error: 1.095088
# Epoch: 78 reconstruction error: 1.093927
# Epoch: 79 reconstruction error: 1.095214
# Epoch: 80 reconstruction error: 1.094064
# Epoch: 81 reconstruction error: 1.093107
# Epoch: 82 reconstruction error: 1.097736
# Epoch: 83 reconstruction error: 1.092147
# Epoch: 84 reconstruction error: 1.093698
# Epoch: 85 reconstruction error: 1.093958
# Epoch: 86 reconstruction error: 1.094264
# Epoch: 87 reconstruction error: 1.093982
# Epoch: 88 reconstruction error: 1.093649
# Epoch: 89 reconstruction error: 1.095405
# Epoch: 90 reconstruction error: 1.092922
# Epoch: 91 reconstruction error: 1.092589
# Epoch: 92 reconstruction error: 1.093353
# Epoch: 93 reconstruction error: 1.093714
# Epoch: 94 reconstruction error: 1.095019
# Epoch: 95 reconstruction error: 1.091591
# Epoch: 96 reconstruction error: 1.092993
# Epoch: 97 reconstruction error: 1.092136
# Epoch: 98 reconstruction error: 1.092389
# Epoch: 99 reconstruction error: 1.092507
# Epoch: 100 reconstruction error: 1.092024
# Epoch: 101 reconstruction error: 1.091277
# Epoch: 102 reconstruction error: 1.091269
# Epoch: 103 reconstruction error: 1.092358
# Epoch: 104 reconstruction error: 1.092546
# Epoch: 105 reconstruction error: 1.090996
# Epoch: 106 reconstruction error: 1.092721
# Epoch: 107 reconstruction error: 1.091575
# Epoch: 108 reconstruction error: 1.091490
# Epoch: 109 reconstruction error: 1.091859
# Epoch: 110 reconstruction error: 1.090776
# Epoch: 111 reconstruction error: 1.089926
# Epoch: 112 reconstruction error: 1.092548
# Epoch: 113 reconstruction error: 1.090693
# Epoch: 114 reconstruction error: 1.090951
# Epoch: 115 reconstruction error: 1.089890
# Epoch: 116 reconstruction error: 1.091833
# Epoch: 117 reconstruction error: 1.090026
# Epoch: 118 reconstruction error: 1.090708
# Epoch: 119 reconstruction error: 1.090700
# Epoch: 120 reconstruction error: 1.090721
# Epoch: 121 reconstruction error: 1.089185
# Epoch: 122 reconstruction error: 1.090680
# Epoch: 123 reconstruction error: 1.089789
# Epoch: 124 reconstruction error: 1.089834
# Epoch: 125 reconstruction error: 1.089592
# Epoch: 126 reconstruction error: 1.089975
# Epoch: 127 reconstruction error: 1.088720
# Epoch: 128 reconstruction error: 1.089056
# Epoch: 129 reconstruction error: 1.089975
# Epoch: 130 reconstruction error: 1.089594
# Epoch: 131 reconstruction error: 1.090600
# Epoch: 132 reconstruction error: 1.087819
# Epoch: 133 reconstruction error: 1.089151
# Epoch: 134 reconstruction error: 1.087983
# Epoch: 135 reconstruction error: 1.087734
# Epoch: 136 reconstruction error: 1.088627
# Epoch: 137 reconstruction error: 1.088392
# Epoch: 138 reconstruction error: 1.087821
# Epoch: 139 reconstruction error: 1.087163
# Epoch: 140 reconstruction error: 1.088289
# Epoch: 141 reconstruction error: 1.087957
# Epoch: 142 reconstruction error: 1.086908
# Epoch: 143 reconstruction error: 1.086843
# Epoch: 144 reconstruction error: 1.087296
# Epoch: 145 reconstruction error: 1.087953
# Epoch: 146 reconstruction error: 1.087942
# Epoch: 147 reconstruction error: 1.086154
# Epoch: 148 reconstruction error: 1.087351
# Epoch: 149 reconstruction error: 1.086269
# Epoch: 150 reconstruction error: 1.087291
# Epoch: 151 reconstruction error: 1.086733
# Epoch: 152 reconstruction error: 1.087451
# Epoch: 153 reconstruction error: 1.086792
# Epoch: 154 reconstruction error: 1.086635
# Epoch: 155 reconstruction error: 1.086694
# Epoch: 156 reconstruction error: 1.086000
# Epoch: 157 reconstruction error: 1.086202
# Epoch: 158 reconstruction error: 1.086192
# Epoch: 159 reconstruction error: 1.086476
# Epoch: 160 reconstruction error: 1.085300
# Epoch: 161 reconstruction error: 1.086460
# Epoch: 162 reconstruction error: 1.086334
# Epoch: 163 reconstruction error: 1.085387
# Epoch: 164 reconstruction error: 1.085883
# Epoch: 165 reconstruction error: 1.085600
# Epoch: 166 reconstruction error: 1.085281
# Epoch: 167 reconstruction error: 1.085693
# Epoch: 168 reconstruction error: 1.084494
# Epoch: 169 reconstruction error: 1.086079
# Epoch: 170 reconstruction error: 1.085562
# Epoch: 171 reconstruction error: 1.085137
# Epoch: 172 reconstruction error: 1.084867
# Epoch: 173 reconstruction error: 1.084926
# Epoch: 174 reconstruction error: 1.083696
# Epoch: 175 reconstruction error: 1.085454
# Epoch: 176 reconstruction error: 1.084429
# Epoch: 177 reconstruction error: 1.083184
# Epoch: 178 reconstruction error: 1.083184
# Epoch: 179 reconstruction error: 1.084576
# Epoch: 180 reconstruction error: 1.084946
# Epoch: 181 reconstruction error: 1.083964
# Epoch: 182 reconstruction error: 1.084574
# Epoch: 183 reconstruction error: 1.084020
# Epoch: 184 reconstruction error: 1.083030
# Epoch: 185 reconstruction error: 1.084574
# Epoch: 186 reconstruction error: 1.084416
# Epoch: 187 reconstruction error: 1.083909
# Epoch: 188 reconstruction error: 1.083791
# Epoch: 189 reconstruction error: 1.084152
# Epoch: 190 reconstruction error: 1.083866
# Epoch: 191 reconstruction error: 1.084134
# Epoch: 192 reconstruction error: 1.083524
# Epoch: 193 reconstruction error: 1.084082
# Epoch: 194 reconstruction error: 1.083256
# Epoch: 195 reconstruction error: 1.084309
# Epoch: 196 reconstruction error: 1.083940
# Epoch: 197 reconstruction error: 1.085343
# Epoch: 198 reconstruction error: 1.083091
# Epoch: 199 reconstruction error: 1.083905
# Epoch: 200 reconstruction error: 1.083905
# Epoch: 201 reconstruction error: 1.082979
# Epoch: 202 reconstruction error: 1.083930
# Epoch: 203 reconstruction error: 1.084002
# Epoch: 204 reconstruction error: 1.083570
# Epoch: 205 reconstruction error: 1.082741
# Epoch: 206 reconstruction error: 1.083312
# Epoch: 207 reconstruction error: 1.083487
# Epoch: 208 reconstruction error: 1.082777
# Epoch: 209 reconstruction error: 1.082554
# Epoch: 210 reconstruction error: 1.083473
# Epoch: 211 reconstruction error: 1.082806
# Epoch: 212 reconstruction error: 1.083271
# Epoch: 213 reconstruction error: 1.082556
# Epoch: 214 reconstruction error: 1.082656
# Epoch: 215 reconstruction error: 1.082486
# Epoch: 216 reconstruction error: 1.083212
# Epoch: 217 reconstruction error: 1.082598
# Epoch: 218 reconstruction error: 1.082296
# Epoch: 219 reconstruction error: 1.082729
# Epoch: 220 reconstruction error: 1.081890
# Epoch: 221 reconstruction error: 1.082096
# Epoch: 222 reconstruction error: 1.082778
# Epoch: 223 reconstruction error: 1.081941
# Epoch: 224 reconstruction error: 1.081939
# Epoch: 225 reconstruction error: 1.082540
# Epoch: 226 reconstruction error: 1.081908
# Epoch: 227 reconstruction error: 1.082175
# Epoch: 228 reconstruction error: 1.081913
# Epoch: 229 reconstruction error: 1.082100
# Epoch: 230 reconstruction error: 1.081938
# Epoch: 231 reconstruction error: 1.081445
# Epoch: 232 reconstruction error: 1.082415
# Epoch: 233 reconstruction error: 1.082000
# Epoch: 234 reconstruction error: 1.081682
# Epoch: 235 reconstruction error: 1.082240
# Epoch: 236 reconstruction error: 1.082651
# Epoch: 237 reconstruction error: 1.081344
# Epoch: 238 reconstruction error: 1.082188
# Epoch: 239 reconstruction error: 1.081506
# Epoch: 240 reconstruction error: 1.081023
# Epoch: 241 reconstruction error: 1.082157
# Epoch: 242 reconstruction error: 1.081836
# Epoch: 243 reconstruction error: 1.081589
# Epoch: 244 reconstruction error: 1.082018
# Epoch: 245 reconstruction error: 1.082829
# Epoch: 246 reconstruction error: 1.081367
# Epoch: 247 reconstruction error: 1.081689
# Epoch: 248 reconstruction error: 1.081354
# Epoch: 249 reconstruction error: 1.080909
# Epoch: 250 reconstruction error: 1.081167
# Epoch: 251 reconstruction error: 1.081120
# Epoch: 252 reconstruction error: 1.080207
# Epoch: 253 reconstruction error: 1.081133
# Epoch: 254 reconstruction error: 1.080757
# Epoch: 255 reconstruction error: 1.081321
# Epoch: 256 reconstruction error: 1.080541
# Epoch: 257 reconstruction error: 1.080899
# Epoch: 258 reconstruction error: 1.080641
# Epoch: 259 reconstruction error: 1.080366
# Epoch: 260 reconstruction error: 1.079851
# Epoch: 261 reconstruction error: 1.080536
# Epoch: 262 reconstruction error: 1.079800
# Epoch: 263 reconstruction error: 1.080197
# Epoch: 264 reconstruction error: 1.079576
# Epoch: 265 reconstruction error: 1.080101
# Epoch: 266 reconstruction error: 1.080150
# Epoch: 267 reconstruction error: 1.080544
# Epoch: 268 reconstruction error: 1.080317
# Epoch: 269 reconstruction error: 1.080277
# Epoch: 270 reconstruction error: 1.080240
# Epoch: 271 reconstruction error: 1.080495
# Epoch: 272 reconstruction error: 1.079981
# Epoch: 273 reconstruction error: 1.079131
# Epoch: 274 reconstruction error: 1.080081
# Epoch: 275 reconstruction error: 1.079486
# Epoch: 276 reconstruction error: 1.080251
# Epoch: 277 reconstruction error: 1.079137
# Epoch: 278 reconstruction error: 1.078900
# Epoch: 279 reconstruction error: 1.079280
# Epoch: 280 reconstruction error: 1.080101
# Epoch: 281 reconstruction error: 1.079080
# Epoch: 282 reconstruction error: 1.079239
# Epoch: 283 reconstruction error: 1.078990
# Epoch: 284 reconstruction error: 1.080384
# Epoch: 285 reconstruction error: 1.078827
# Epoch: 286 reconstruction error: 1.079420
# Epoch: 287 reconstruction error: 1.079348
# Epoch: 288 reconstruction error: 1.079162
# Epoch: 289 reconstruction error: 1.078969
# Epoch: 290 reconstruction error: 1.079458
# Epoch: 291 reconstruction error: 1.079157
# Epoch: 292 reconstruction error: 1.079044
# Epoch: 293 reconstruction error: 1.079172
# Epoch: 294 reconstruction error: 1.078612
# Epoch: 295 reconstruction error: 1.078879
# Epoch: 296 reconstruction error: 1.078904
# Epoch: 297 reconstruction error: 1.078666
# Epoch: 298 reconstruction error: 1.078226
# Epoch: 299 reconstruction error: 1.079559
# Epoch: 300 reconstruction error: 1.078176
# Epoch: 301 reconstruction error: 1.078832
# Epoch: 302 reconstruction error: 1.078572
# Epoch: 303 reconstruction error: 1.078375
# Epoch: 304 reconstruction error: 1.078361
# Epoch: 305 reconstruction error: 1.079494
# Epoch: 306 reconstruction error: 1.077988
# Epoch: 307 reconstruction error: 1.079021
# Epoch: 308 reconstruction error: 1.078096
# Epoch: 309 reconstruction error: 1.077940
# Epoch: 310 reconstruction error: 1.078557
# Epoch: 311 reconstruction error: 1.078418
# Epoch: 312 reconstruction error: 1.078223
# Epoch: 313 reconstruction error: 1.077896
# Epoch: 314 reconstruction error: 1.078266
# Epoch: 315 reconstruction error: 1.078040
# Epoch: 316 reconstruction error: 1.077687
# Epoch: 317 reconstruction error: 1.078339
# Epoch: 318 reconstruction error: 1.078280
# Epoch: 319 reconstruction error: 1.077999
# Epoch: 320 reconstruction error: 1.077458
# Epoch: 321 reconstruction error: 1.077939
# Epoch: 322 reconstruction error: 1.077996
# Epoch: 323 reconstruction error: 1.077412
# Epoch: 324 reconstruction error: 1.078529
# Epoch: 325 reconstruction error: 1.077641
# Epoch: 326 reconstruction error: 1.077927
# Epoch: 327 reconstruction error: 1.078109
# Epoch: 328 reconstruction error: 1.078212
# Epoch: 329 reconstruction error: 1.077786
# Epoch: 330 reconstruction error: 1.077845
# Epoch: 331 reconstruction error: 1.077983
# Epoch: 332 reconstruction error: 1.078279
# Epoch: 333 reconstruction error: 1.077726
# Epoch: 334 reconstruction error: 1.078123
# Epoch: 335 reconstruction error: 1.077976
# Epoch: 336 reconstruction error: 1.078220
# Epoch: 337 reconstruction error: 1.078233
# Epoch: 338 reconstruction error: 1.078074
# Epoch: 339 reconstruction error: 1.077659
# Epoch: 340 reconstruction error: 1.078107
# Epoch: 341 reconstruction error: 1.077379
# Epoch: 342 reconstruction error: 1.078550
# Epoch: 343 reconstruction error: 1.077229
# Epoch: 344 reconstruction error: 1.077500
# Epoch: 345 reconstruction error: 1.077045
# Epoch: 346 reconstruction error: 1.078434
# Epoch: 347 reconstruction error: 1.077299
# Epoch: 348 reconstruction error: 1.077471
# Epoch: 349 reconstruction error: 1.077726
# Epoch: 350 reconstruction error: 1.077266
# Epoch: 351 reconstruction error: 1.077523
# Epoch: 352 reconstruction error: 1.077896
# Epoch: 353 reconstruction error: 1.077366
# Epoch: 354 reconstruction error: 1.077865
# Epoch: 355 reconstruction error: 1.077059
# Epoch: 356 reconstruction error: 1.077371
# Epoch: 357 reconstruction error: 1.077407
# Epoch: 358 reconstruction error: 1.076707
# Epoch: 359 reconstruction error: 1.077237
# Epoch: 360 reconstruction error: 1.077090
# Epoch: 361 reconstruction error: 1.076900
# Epoch: 362 reconstruction error: 1.077297
# Epoch: 363 reconstruction error: 1.077263
# Epoch: 364 reconstruction error: 1.077199
# Epoch: 365 reconstruction error: 1.077356
# Epoch: 366 reconstruction error: 1.077052
# Epoch: 367 reconstruction error: 1.077108
# Epoch: 368 reconstruction error: 1.076622
# Epoch: 369 reconstruction error: 1.077011
# Epoch: 370 reconstruction error: 1.076681
# Epoch: 371 reconstruction error: 1.077343
# Epoch: 372 reconstruction error: 1.076756
# Epoch: 373 reconstruction error: 1.077160
# Epoch: 374 reconstruction error: 1.076645
# Epoch: 375 reconstruction error: 1.076805
# Epoch: 376 reconstruction error: 1.076519
# Epoch: 377 reconstruction error: 1.076777
# Epoch: 378 reconstruction error: 1.076205
# Epoch: 379 reconstruction error: 1.076818
# Epoch: 380 reconstruction error: 1.076540
# Epoch: 381 reconstruction error: 1.076857
# Epoch: 382 reconstruction error: 1.076743
# Epoch: 383 reconstruction error: 1.076606
# Epoch: 384 reconstruction error: 1.076612
# Epoch: 385 reconstruction error: 1.076203
# Epoch: 386 reconstruction error: 1.076422
# Epoch: 387 reconstruction error: 1.076398
# Epoch: 388 reconstruction error: 1.075868
# Epoch: 389 reconstruction error: 1.076311
# Epoch: 390 reconstruction error: 1.076341
# Epoch: 391 reconstruction error: 1.076439
# Epoch: 392 reconstruction error: 1.076519
# Epoch: 393 reconstruction error: 1.076357
# Epoch: 394 reconstruction error: 1.076193
# Epoch: 395 reconstruction error: 1.076265
# Epoch: 396 reconstruction error: 1.076128
# Epoch: 397 reconstruction error: 1.076504
# Epoch: 398 reconstruction error: 1.076228
# Epoch: 399 reconstruction error: 1.076524
# Epoch: 400 reconstruction error: 1.076167
# Epoch: 401 reconstruction error: 1.076383
# Epoch: 402 reconstruction error: 1.075987
# Epoch: 403 reconstruction error: 1.076429
# Epoch: 404 reconstruction error: 1.075982
# Epoch: 405 reconstruction error: 1.076020
# Epoch: 406 reconstruction error: 1.075889
# Epoch: 407 reconstruction error: 1.076599
# Epoch: 408 reconstruction error: 1.075874
# Epoch: 409 reconstruction error: 1.076028
# Epoch: 410 reconstruction error: 1.076174
# Epoch: 411 reconstruction error: 1.075752
# Epoch: 412 reconstruction error: 1.075451
# Epoch: 413 reconstruction error: 1.075992
# Epoch: 414 reconstruction error: 1.075856
# Epoch: 415 reconstruction error: 1.076380
# Epoch: 416 reconstruction error: 1.075641
# Epoch: 417 reconstruction error: 1.076255
# Epoch: 418 reconstruction error: 1.075755
# Epoch: 419 reconstruction error: 1.076148
# Epoch: 420 reconstruction error: 1.075516
# Epoch: 421 reconstruction error: 1.075886
# Epoch: 422 reconstruction error: 1.075443
# Epoch: 423 reconstruction error: 1.075830
# Epoch: 424 reconstruction error: 1.075519
# Epoch: 425 reconstruction error: 1.075925
# Epoch: 426 reconstruction error: 1.075570
# Epoch: 427 reconstruction error: 1.075809
# Epoch: 428 reconstruction error: 1.075719
# Epoch: 429 reconstruction error: 1.075958
# Epoch: 430 reconstruction error: 1.076192
# Epoch: 431 reconstruction error: 1.076077
# Epoch: 432 reconstruction error: 1.076326
# Epoch: 433 reconstruction error: 1.076097
# Epoch: 434 reconstruction error: 1.076113
# Epoch: 435 reconstruction error: 1.075858
# Epoch: 436 reconstruction error: 1.075755
# Epoch: 437 reconstruction error: 1.076262
# Epoch: 438 reconstruction error: 1.075680
# Epoch: 439 reconstruction error: 1.075457
# Epoch: 440 reconstruction error: 1.075806
# Epoch: 441 reconstruction error: 1.075505
# Epoch: 442 reconstruction error: 1.075065
# Epoch: 443 reconstruction error: 1.075714
# Epoch: 444 reconstruction error: 1.075575
# Epoch: 445 reconstruction error: 1.075608
# Epoch: 446 reconstruction error: 1.074952
# Epoch: 447 reconstruction error: 1.075070
# Epoch: 448 reconstruction error: 1.075081
# Epoch: 449 reconstruction error: 1.075905
# Epoch: 450 reconstruction error: 1.074708
# Epoch: 451 reconstruction error: 1.075307
# Epoch: 452 reconstruction error: 1.075027
# Epoch: 453 reconstruction error: 1.075127
# Epoch: 454 reconstruction error: 1.074558
# Epoch: 455 reconstruction error: 1.075534
# Epoch: 456 reconstruction error: 1.074718
# Epoch: 457 reconstruction error: 1.075418
# Epoch: 458 reconstruction error: 1.075318
# Epoch: 459 reconstruction error: 1.075196
# Epoch: 460 reconstruction error: 1.075317
# Epoch: 461 reconstruction error: 1.075657
# Epoch: 462 reconstruction error: 1.074957
# Epoch: 463 reconstruction error: 1.075668
# Epoch: 464 reconstruction error: 1.075310
# Epoch: 465 reconstruction error: 1.075613
# Epoch: 466 reconstruction error: 1.074448
# Epoch: 467 reconstruction error: 1.075829
# Epoch: 468 reconstruction error: 1.074955
# Epoch: 469 reconstruction error: 1.075976
# Epoch: 470 reconstruction error: 1.075377
# Epoch: 471 reconstruction error: 1.075997
# Epoch: 472 reconstruction error: 1.075125
# Epoch: 473 reconstruction error: 1.075919
# Epoch: 474 reconstruction error: 1.075179
# Epoch: 475 reconstruction error: 1.075608
# Epoch: 476 reconstruction error: 1.075657
# Epoch: 477 reconstruction error: 1.075763
# Epoch: 478 reconstruction error: 1.075346
# Epoch: 479 reconstruction error: 1.075480
# Epoch: 480 reconstruction error: 1.074839
# Epoch: 481 reconstruction error: 1.075356
# Epoch: 482 reconstruction error: 1.075289
# Epoch: 483 reconstruction error: 1.075722
# Epoch: 484 reconstruction error: 1.074767
# Epoch: 485 reconstruction error: 1.075387
# Epoch: 486 reconstruction error: 1.074888
# Epoch: 487 reconstruction error: 1.074875
# Epoch: 488 reconstruction error: 1.075482
# Epoch: 489 reconstruction error: 1.075240
# Epoch: 490 reconstruction error: 1.075266
# Epoch: 491 reconstruction error: 1.074852
# Epoch: 492 reconstruction error: 1.075308
# Epoch: 493 reconstruction error: 1.075058
# Epoch: 494 reconstruction error: 1.074834
# Epoch: 495 reconstruction error: 1.075232
# Epoch: 496 reconstruction error: 1.074885
# Epoch: 497 reconstruction error: 1.075112
# Epoch: 498 reconstruction error: 1.075076
# Epoch: 499 reconstruction error: 1.074970
# Epoch: 500 reconstruction error: 1.075065
# Epoch: 501 reconstruction error: 1.074821
# Epoch: 502 reconstruction error: 1.074829
# Epoch: 503 reconstruction error: 1.075245
# Epoch: 504 reconstruction error: 1.075022
# Epoch: 505 reconstruction error: 1.075052
# Epoch: 506 reconstruction error: 1.075312
# Epoch: 507 reconstruction error: 1.074790
# Epoch: 508 reconstruction error: 1.074947
# Epoch: 509 reconstruction error: 1.075434
# Epoch: 510 reconstruction error: 1.074816
# Epoch: 511 reconstruction error: 1.074955
# Epoch: 512 reconstruction error: 1.074566
# Epoch: 513 reconstruction error: 1.074769
# Epoch: 514 reconstruction error: 1.075009
# Epoch: 515 reconstruction error: 1.074934
# Epoch: 516 reconstruction error: 1.074746
# Epoch: 517 reconstruction error: 1.074646
# Epoch: 518 reconstruction error: 1.074533
# Epoch: 519 reconstruction error: 1.074659
# Epoch: 520 reconstruction error: 1.074515
# Epoch: 521 reconstruction error: 1.075001
# Epoch: 522 reconstruction error: 1.074414
# Epoch: 523 reconstruction error: 1.074864
# Epoch: 524 reconstruction error: 1.074327
# Epoch: 525 reconstruction error: 1.074584
# Epoch: 526 reconstruction error: 1.074640
# Epoch: 527 reconstruction error: 1.074540
# Epoch: 528 reconstruction error: 1.074456
# Epoch: 529 reconstruction error: 1.074605
# Epoch: 530 reconstruction error: 1.074438
# Epoch: 531 reconstruction error: 1.074448
# Epoch: 532 reconstruction error: 1.074054
# Epoch: 533 reconstruction error: 1.074571
# Epoch: 534 reconstruction error: 1.074162
# Epoch: 535 reconstruction error: 1.075014
# Epoch: 536 reconstruction error: 1.074160
# Epoch: 537 reconstruction error: 1.074293
# Epoch: 538 reconstruction error: 1.074525
# Epoch: 539 reconstruction error: 1.074329
# Epoch: 540 reconstruction error: 1.074255
# Epoch: 541 reconstruction error: 1.074512
# Epoch: 542 reconstruction error: 1.073992
# Epoch: 543 reconstruction error: 1.074294
# Epoch: 544 reconstruction error: 1.074105
# Epoch: 545 reconstruction error: 1.074229
# Epoch: 546 reconstruction error: 1.074208
# Epoch: 547 reconstruction error: 1.074484
# Epoch: 548 reconstruction error: 1.074098
# Epoch: 549 reconstruction error: 1.074150
# Epoch: 550 reconstruction error: 1.074007
# Epoch: 551 reconstruction error: 1.074314
# Epoch: 552 reconstruction error: 1.074826
# Epoch: 553 reconstruction error: 1.074659
# Epoch: 554 reconstruction error: 1.074000
# Epoch: 555 reconstruction error: 1.074376
# Epoch: 556 reconstruction error: 1.074296
# Epoch: 557 reconstruction error: 1.074512
# Epoch: 558 reconstruction error: 1.074255
# Epoch: 559 reconstruction error: 1.074043
# Epoch: 560 reconstruction error: 1.074268
# Epoch: 561 reconstruction error: 1.074409
# Epoch: 562 reconstruction error: 1.074391
# Epoch: 563 reconstruction error: 1.074278
# Epoch: 564 reconstruction error: 1.074466
# Epoch: 565 reconstruction error: 1.074532
# Epoch: 566 reconstruction error: 1.074329
# Epoch: 567 reconstruction error: 1.074592
# Epoch: 568 reconstruction error: 1.074671
# Epoch: 569 reconstruction error: 1.074339
# Epoch: 570 reconstruction error: 1.074481
# Epoch: 571 reconstruction error: 1.074896
# Epoch: 572 reconstruction error: 1.074283
# Epoch: 573 reconstruction error: 1.074579
# Epoch: 574 reconstruction error: 1.074456
# Epoch: 575 reconstruction error: 1.074486
# Epoch: 576 reconstruction error: 1.074465
# Epoch: 577 reconstruction error: 1.074533
# Epoch: 578 reconstruction error: 1.074440
# Epoch: 579 reconstruction error: 1.074533
# Epoch: 580 reconstruction error: 1.074005
# Epoch: 581 reconstruction error: 1.074185
# Epoch: 582 reconstruction error: 1.074128
# Epoch: 583 reconstruction error: 1.074062
# Epoch: 584 reconstruction error: 1.074178
# Epoch: 585 reconstruction error: 1.074007
# Epoch: 586 reconstruction error: 1.074015
# Epoch: 587 reconstruction error: 1.074299
# Epoch: 588 reconstruction error: 1.073678
# Epoch: 589 reconstruction error: 1.074239
# Epoch: 590 reconstruction error: 1.073771
# Epoch: 591 reconstruction error: 1.074010
# Epoch: 592 reconstruction error: 1.073694
# Epoch: 593 reconstruction error: 1.073872
# Epoch: 594 reconstruction error: 1.073491
# Epoch: 595 reconstruction error: 1.073756
# Epoch: 596 reconstruction error: 1.073632
# Epoch: 597 reconstruction error: 1.074007
# Epoch: 598 reconstruction error: 1.073596
# Epoch: 599 reconstruction error: 1.073589
# Epoch: 600 reconstruction error: 1.074002
# Epoch: 601 reconstruction error: 1.073766
# Epoch: 602 reconstruction error: 1.073464
# Epoch: 603 reconstruction error: 1.074172
# Epoch: 604 reconstruction error: 1.073617
# Epoch: 605 reconstruction error: 1.074062
# Epoch: 606 reconstruction error: 1.073877
# Epoch: 607 reconstruction error: 1.074283
# Epoch: 608 reconstruction error: 1.073807
# Epoch: 609 reconstruction error: 1.074546
# Epoch: 610 reconstruction error: 1.073920
# Epoch: 611 reconstruction error: 1.074190
# Epoch: 612 reconstruction error: 1.073776
# Epoch: 613 reconstruction error: 1.073895
# Epoch: 614 reconstruction error: 1.073810
# Epoch: 615 reconstruction error: 1.073681
# Epoch: 616 reconstruction error: 1.073748
# Epoch: 617 reconstruction error: 1.073675
# Epoch: 618 reconstruction error: 1.073406
# Epoch: 619 reconstruction error: 1.073794
# Epoch: 620 reconstruction error: 1.073737
# Epoch: 621 reconstruction error: 1.073827
# Epoch: 622 reconstruction error: 1.073905
# Epoch: 623 reconstruction error: 1.073421
# Epoch: 624 reconstruction error: 1.073773
# Epoch: 625 reconstruction error: 1.073792
# Epoch: 626 reconstruction error: 1.073807
# Epoch: 627 reconstruction error: 1.073768
# Epoch: 628 reconstruction error: 1.073738
# Epoch: 629 reconstruction error: 1.074046
# Epoch: 630 reconstruction error: 1.073879
# Epoch: 631 reconstruction error: 1.073900
# Epoch: 632 reconstruction error: 1.073637
# Epoch: 633 reconstruction error: 1.073753
# Epoch: 634 reconstruction error: 1.073611
# Epoch: 635 reconstruction error: 1.073735
# Epoch: 636 reconstruction error: 1.073746
# Epoch: 637 reconstruction error: 1.073517
# Epoch: 638 reconstruction error: 1.074167
# Epoch: 639 reconstruction error: 1.073480
# Epoch: 640 reconstruction error: 1.073553
# Epoch: 641 reconstruction error: 1.073617
# Epoch: 642 reconstruction error: 1.073632
# Epoch: 643 reconstruction error: 1.073362
# Epoch: 644 reconstruction error: 1.073648
# Epoch: 645 reconstruction error: 1.073164
# Epoch: 646 reconstruction error: 1.073398
# Epoch: 647 reconstruction error: 1.073506
# Epoch: 648 reconstruction error: 1.073814
# Epoch: 649 reconstruction error: 1.072958
# Epoch: 650 reconstruction error: 1.074062
# Epoch: 651 reconstruction error: 1.073472
# Epoch: 652 reconstruction error: 1.073452
# Epoch: 653 reconstruction error: 1.073447
# Epoch: 654 reconstruction error: 1.073925
# Epoch: 655 reconstruction error: 1.073639
# Epoch: 656 reconstruction error: 1.073486
# Epoch: 657 reconstruction error: 1.073288
# Epoch: 658 reconstruction error: 1.073781
# Epoch: 659 reconstruction error: 1.073127
# Epoch: 660 reconstruction error: 1.074062
# Epoch: 661 reconstruction error: 1.073663
# Epoch: 662 reconstruction error: 1.073460
# Epoch: 663 reconstruction error: 1.073588
# Epoch: 664 reconstruction error: 1.073737
# Epoch: 665 reconstruction error: 1.073351
# Epoch: 666 reconstruction error: 1.073902
# Epoch: 667 reconstruction error: 1.073629
# Epoch: 668 reconstruction error: 1.074124
# Epoch: 669 reconstruction error: 1.073643
# Epoch: 670 reconstruction error: 1.073805
# Epoch: 671 reconstruction error: 1.073410
# Epoch: 672 reconstruction error: 1.073814
# Epoch: 673 reconstruction error: 1.073468
# Epoch: 674 reconstruction error: 1.073293
# Epoch: 675 reconstruction error: 1.073717
# Epoch: 676 reconstruction error: 1.073900
# Epoch: 677 reconstruction error: 1.073356
# Epoch: 678 reconstruction error: 1.074191
# Epoch: 679 reconstruction error: 1.073465
# Epoch: 680 reconstruction error: 1.073522
# Epoch: 681 reconstruction error: 1.073632
# Epoch: 682 reconstruction error: 1.073814
# Epoch: 683 reconstruction error: 1.073346
# Epoch: 684 reconstruction error: 1.074054
# Epoch: 685 reconstruction error: 1.073328
# Epoch: 686 reconstruction error: 1.073351
# Epoch: 687 reconstruction error: 1.073689
# Epoch: 688 reconstruction error: 1.073774
# Epoch: 689 reconstruction error: 1.073375
# Epoch: 690 reconstruction error: 1.073581
# Epoch: 691 reconstruction error: 1.073764
# Epoch: 692 reconstruction error: 1.073473
# Epoch: 693 reconstruction error: 1.073650
# Epoch: 694 reconstruction error: 1.073760
# Epoch: 695 reconstruction error: 1.073732
# Epoch: 696 reconstruction error: 1.073771
# Epoch: 697 reconstruction error: 1.073521
# Epoch: 698 reconstruction error: 1.073694
# Epoch: 699 reconstruction error: 1.073516
# Epoch: 700 reconstruction error: 1.073652
# Epoch: 701 reconstruction error: 1.073465
# Epoch: 702 reconstruction error: 1.073977
# Epoch: 703 reconstruction error: 1.073655
# Epoch: 704 reconstruction error: 1.073890
# Epoch: 705 reconstruction error: 1.073881
# Epoch: 706 reconstruction error: 1.073851
# Epoch: 707 reconstruction error: 1.073637
# Epoch: 708 reconstruction error: 1.074208
# Epoch: 709 reconstruction error: 1.073864
# Epoch: 710 reconstruction error: 1.073812
# Epoch: 711 reconstruction error: 1.073666
# Epoch: 712 reconstruction error: 1.073910
# Epoch: 713 reconstruction error: 1.073776
# Epoch: 714 reconstruction error: 1.073591
# Epoch: 715 reconstruction error: 1.073863
# Epoch: 716 reconstruction error: 1.073979
# Epoch: 717 reconstruction error: 1.073414
# Epoch: 718 reconstruction error: 1.073964
# Epoch: 719 reconstruction error: 1.073532
# Epoch: 720 reconstruction error: 1.073653
# Epoch: 721 reconstruction error: 1.073498
# Epoch: 722 reconstruction error: 1.073815
# Epoch: 723 reconstruction error: 1.073527
# Epoch: 724 reconstruction error: 1.073699
# Epoch: 725 reconstruction error: 1.073277
# Epoch: 726 reconstruction error: 1.073665
# Epoch: 727 reconstruction error: 1.073295
# Epoch: 728 reconstruction error: 1.073571
# Epoch: 729 reconstruction error: 1.073452
# Epoch: 730 reconstruction error: 1.073712
# Epoch: 731 reconstruction error: 1.073154
# Epoch: 732 reconstruction error: 1.073480
# Epoch: 733 reconstruction error: 1.073468
# Epoch: 734 reconstruction error: 1.073583
# Epoch: 735 reconstruction error: 1.073195
# Epoch: 736 reconstruction error: 1.073917
# Epoch: 737 reconstruction error: 1.073599
# Epoch: 738 reconstruction error: 1.073181
# Epoch: 739 reconstruction error: 1.073951
# Epoch: 740 reconstruction error: 1.073351
# Epoch: 741 reconstruction error: 1.073642
# Epoch: 742 reconstruction error: 1.073786
# Epoch: 743 reconstruction error: 1.072922
# Epoch: 744 reconstruction error: 1.073506
# Epoch: 745 reconstruction error: 1.073568
# Epoch: 746 reconstruction error: 1.073393
# Epoch: 747 reconstruction error: 1.073202
# Epoch: 748 reconstruction error: 1.073969
# Epoch: 749 reconstruction error: 1.073460
# Epoch: 750 reconstruction error: 1.073369
# Epoch: 751 reconstruction error: 1.073709
# Epoch: 752 reconstruction error: 1.073272
# Epoch: 753 reconstruction error: 1.073807
# Epoch: 754 reconstruction error: 1.073817
# Epoch: 755 reconstruction error: 1.073593
# Epoch: 756 reconstruction error: 1.073478
# Epoch: 757 reconstruction error: 1.073732
# Epoch: 758 reconstruction error: 1.073372
# Epoch: 759 reconstruction error: 1.073570
# Epoch: 760 reconstruction error: 1.073717
# Epoch: 761 reconstruction error: 1.073624
# Epoch: 762 reconstruction error: 1.073697
# Epoch: 763 reconstruction error: 1.073524
# Epoch: 764 reconstruction error: 1.073509
# Epoch: 765 reconstruction error: 1.073730
# Epoch: 766 reconstruction error: 1.073814
# Epoch: 767 reconstruction error: 1.073228
# Epoch: 768 reconstruction error: 1.073907
# Epoch: 769 reconstruction error: 1.073591
# Epoch: 770 reconstruction error: 1.073267
# Epoch: 771 reconstruction error: 1.073357
# Epoch: 772 reconstruction error: 1.073688
# Epoch: 773 reconstruction error: 1.073501
# Epoch: 774 reconstruction error: 1.073421
# Epoch: 775 reconstruction error: 1.073549
# Epoch: 776 reconstruction error: 1.073537
# Epoch: 777 reconstruction error: 1.073239
# Epoch: 778 reconstruction error: 1.073552
# Epoch: 779 reconstruction error: 1.073217
# Epoch: 780 reconstruction error: 1.073392
# Epoch: 781 reconstruction error: 1.073614
# Epoch: 782 reconstruction error: 1.073275
# Epoch: 783 reconstruction error: 1.073524
# Epoch: 784 reconstruction error: 1.073989
# Epoch: 785 reconstruction error: 1.073781
# Epoch: 786 reconstruction error: 1.073403
# Epoch: 787 reconstruction error: 1.073383
# Epoch: 788 reconstruction error: 1.073671
# Epoch: 789 reconstruction error: 1.073323
# Epoch: 790 reconstruction error: 1.073643
# Epoch: 791 reconstruction error: 1.073310
# Epoch: 792 reconstruction error: 1.073290
# Epoch: 793 reconstruction error: 1.073603
# Epoch: 794 reconstruction error: 1.073346
# Epoch: 795 reconstruction error: 1.073382
# Epoch: 796 reconstruction error: 1.073431
# Epoch: 797 reconstruction error: 1.073555
# Epoch: 798 reconstruction error: 1.073217
# Epoch: 799 reconstruction error: 1.073478
# Epoch: 800 reconstruction error: 1.073475
# Epoch: 801 reconstruction error: 1.073352
# Epoch: 802 reconstruction error: 1.073444
# Epoch: 803 reconstruction error: 1.072799
# Epoch: 804 reconstruction error: 1.073509
# Epoch: 805 reconstruction error: 1.073230
# Epoch: 806 reconstruction error: 1.073385
# Epoch: 807 reconstruction error: 1.073378
# Epoch: 808 reconstruction error: 1.073517
# Epoch: 809 reconstruction error: 1.073328
# Epoch: 810 reconstruction error: 1.073185
# Epoch: 811 reconstruction error: 1.072958
# Epoch: 812 reconstruction error: 1.073411
# Epoch: 813 reconstruction error: 1.073076
# Epoch: 814 reconstruction error: 1.073516
# Epoch: 815 reconstruction error: 1.072533
# Epoch: 816 reconstruction error: 1.073228
# Epoch: 817 reconstruction error: 1.073228
# Epoch: 818 reconstruction error: 1.073130
# Epoch: 819 reconstruction error: 1.072757
# Epoch: 820 reconstruction error: 1.073639
# Epoch: 821 reconstruction error: 1.073118
# Epoch: 822 reconstruction error: 1.073120
# Epoch: 823 reconstruction error: 1.072909
# Epoch: 824 reconstruction error: 1.073171
# Epoch: 825 reconstruction error: 1.073076
# Epoch: 826 reconstruction error: 1.073128
# Epoch: 827 reconstruction error: 1.072860
# Epoch: 828 reconstruction error: 1.073123
# Epoch: 829 reconstruction error: 1.073086
# Epoch: 830 reconstruction error: 1.073001
# Epoch: 831 reconstruction error: 1.072641
# Epoch: 832 reconstruction error: 1.073311
# Epoch: 833 reconstruction error: 1.072981
# Epoch: 834 reconstruction error: 1.073228
# Epoch: 835 reconstruction error: 1.072688
# Epoch: 836 reconstruction error: 1.073264
# Epoch: 837 reconstruction error: 1.072816
# Epoch: 838 reconstruction error: 1.072875
# Epoch: 839 reconstruction error: 1.072821
# Epoch: 840 reconstruction error: 1.072811
# Epoch: 841 reconstruction error: 1.072724
# Epoch: 842 reconstruction error: 1.072777
# Epoch: 843 reconstruction error: 1.072402
# Epoch: 844 reconstruction error: 1.073014
# Epoch: 845 reconstruction error: 1.072804
# Epoch: 846 reconstruction error: 1.072538
# Epoch: 847 reconstruction error: 1.072786
# Epoch: 848 reconstruction error: 1.073060
# Epoch: 849 reconstruction error: 1.072709
# Epoch: 850 reconstruction error: 1.072785
# Epoch: 851 reconstruction error: 1.072503
# Epoch: 852 reconstruction error: 1.072814
# Epoch: 853 reconstruction error: 1.072191
# Epoch: 854 reconstruction error: 1.072731
# Epoch: 855 reconstruction error: 1.072405
# Epoch: 856 reconstruction error: 1.072279
# Epoch: 857 reconstruction error: 1.072456
# Epoch: 858 reconstruction error: 1.072796
# Epoch: 859 reconstruction error: 1.072536
# Epoch: 860 reconstruction error: 1.072659
# Epoch: 861 reconstruction error: 1.072376
# Epoch: 862 reconstruction error: 1.072708
# Epoch: 863 reconstruction error: 1.072304
# Epoch: 864 reconstruction error: 1.072891
# Epoch: 865 reconstruction error: 1.072407
# Epoch: 866 reconstruction error: 1.072516
# Epoch: 867 reconstruction error: 1.072240
# Epoch: 868 reconstruction error: 1.072520
# Epoch: 869 reconstruction error: 1.072708
# Epoch: 870 reconstruction error: 1.072446
# Epoch: 871 reconstruction error: 1.072379
# Epoch: 872 reconstruction error: 1.072986
# Epoch: 873 reconstruction error: 1.072466
# Epoch: 874 reconstruction error: 1.072831
# Epoch: 875 reconstruction error: 1.072705
# Epoch: 876 reconstruction error: 1.072551
# Epoch: 877 reconstruction error: 1.072703
# Epoch: 878 reconstruction error: 1.072530
# Epoch: 879 reconstruction error: 1.072835
# Epoch: 880 reconstruction error: 1.072644
# Epoch: 881 reconstruction error: 1.072584
# Epoch: 882 reconstruction error: 1.073007
# Epoch: 883 reconstruction error: 1.072204
# Epoch: 884 reconstruction error: 1.073125
# Epoch: 885 reconstruction error: 1.072409
# Epoch: 886 reconstruction error: 1.072970
# Epoch: 887 reconstruction error: 1.072602
# Epoch: 888 reconstruction error: 1.072176
# Epoch: 889 reconstruction error: 1.072737
# Epoch: 890 reconstruction error: 1.072829
# Epoch: 891 reconstruction error: 1.072325
# Epoch: 892 reconstruction error: 1.072914
# Epoch: 893 reconstruction error: 1.072358
# Epoch: 894 reconstruction error: 1.072518
# Epoch: 895 reconstruction error: 1.072212
# Epoch: 896 reconstruction error: 1.072675
# Epoch: 897 reconstruction error: 1.072381
# Epoch: 898 reconstruction error: 1.072471
# Epoch: 899 reconstruction error: 1.072410
# Epoch: 900 reconstruction error: 1.072428
# Epoch: 901 reconstruction error: 1.072160
# Epoch: 902 reconstruction error: 1.072772
# Epoch: 903 reconstruction error: 1.072116
# Epoch: 904 reconstruction error: 1.072603
# Epoch: 905 reconstruction error: 1.072438
# Epoch: 906 reconstruction error: 1.072592
# Epoch: 907 reconstruction error: 1.072356
# Epoch: 908 reconstruction error: 1.072456
# Epoch: 909 reconstruction error: 1.072425
# Epoch: 910 reconstruction error: 1.072520
# Epoch: 911 reconstruction error: 1.072464
# Epoch: 912 reconstruction error: 1.072865
# Epoch: 913 reconstruction error: 1.072196
# Epoch: 914 reconstruction error: 1.072693
# Epoch: 915 reconstruction error: 1.072070
# Epoch: 916 reconstruction error: 1.072572
# Epoch: 917 reconstruction error: 1.072564
# Epoch: 918 reconstruction error: 1.072549
# Epoch: 919 reconstruction error: 1.072351
# Epoch: 920 reconstruction error: 1.072521
# Epoch: 921 reconstruction error: 1.072080
# Epoch: 922 reconstruction error: 1.072706
# Epoch: 923 reconstruction error: 1.071949
# Epoch: 924 reconstruction error: 1.072700
# Epoch: 925 reconstruction error: 1.072489
# Epoch: 926 reconstruction error: 1.072359
# Epoch: 927 reconstruction error: 1.072613
# Epoch: 928 reconstruction error: 1.072350
# Epoch: 929 reconstruction error: 1.072248
# Epoch: 930 reconstruction error: 1.072912
# Epoch: 931 reconstruction error: 1.072116
# Epoch: 932 reconstruction error: 1.072399
# Epoch: 933 reconstruction error: 1.071929
# Epoch: 934 reconstruction error: 1.072500
# Epoch: 935 reconstruction error: 1.072081
# Epoch: 936 reconstruction error: 1.072327
# Epoch: 937 reconstruction error: 1.072245
# Epoch: 938 reconstruction error: 1.071933
# Epoch: 939 reconstruction error: 1.071900
# Epoch: 940 reconstruction error: 1.072482
# Epoch: 941 reconstruction error: 1.071880
# Epoch: 942 reconstruction error: 1.072428
# Epoch: 943 reconstruction error: 1.072059
# Epoch: 944 reconstruction error: 1.072386
# Epoch: 945 reconstruction error: 1.071820
# Epoch: 946 reconstruction error: 1.072327
# Epoch: 947 reconstruction error: 1.071895
# Epoch: 948 reconstruction error: 1.072148
# Epoch: 949 reconstruction error: 1.071834
# Epoch: 950 reconstruction error: 1.072165
# Epoch: 951 reconstruction error: 1.071738
# Epoch: 952 reconstruction error: 1.072260
# Epoch: 953 reconstruction error: 1.072276
# Epoch: 954 reconstruction error: 1.072253
# Epoch: 955 reconstruction error: 1.071843
# Epoch: 956 reconstruction error: 1.072258
# Epoch: 957 reconstruction error: 1.072072
# Epoch: 958 reconstruction error: 1.072062
# Epoch: 959 reconstruction error: 1.072145
# Epoch: 960 reconstruction error: 1.072021
# Epoch: 961 reconstruction error: 1.071450
# Epoch: 962 reconstruction error: 1.072325
# Epoch: 963 reconstruction error: 1.071893
# Epoch: 964 reconstruction error: 1.072000
# Epoch: 965 reconstruction error: 1.072237
# Epoch: 966 reconstruction error: 1.071949
# Epoch: 967 reconstruction error: 1.072096
# Epoch: 968 reconstruction error: 1.071730
# Epoch: 969 reconstruction error: 1.071700
# Epoch: 970 reconstruction error: 1.071682
# Epoch: 971 reconstruction error: 1.071620
# Epoch: 972 reconstruction error: 1.071942
# Epoch: 973 reconstruction error: 1.071543
# Epoch: 974 reconstruction error: 1.071498
# Epoch: 975 reconstruction error: 1.072000
# Epoch: 976 reconstruction error: 1.071895
# Epoch: 977 reconstruction error: 1.071905
# Epoch: 978 reconstruction error: 1.072078
# Epoch: 979 reconstruction error: 1.071406
# Epoch: 980 reconstruction error: 1.071782
# Epoch: 981 reconstruction error: 1.071699
# Epoch: 982 reconstruction error: 1.071918
# Epoch: 983 reconstruction error: 1.071892
# Epoch: 984 reconstruction error: 1.072160
# Epoch: 985 reconstruction error: 1.071903
# Epoch: 986 reconstruction error: 1.071995
# Epoch: 987 reconstruction error: 1.071720
# Epoch: 988 reconstruction error: 1.071866
# Epoch: 989 reconstruction error: 1.071514
# Epoch: 990 reconstruction error: 1.072055
# Epoch: 991 reconstruction error: 1.071725
# Epoch: 992 reconstruction error: 1.071970
# Epoch: 993 reconstruction error: 1.071658
# Epoch: 994 reconstruction error: 1.071746
# Epoch: 995 reconstruction error: 1.071591
# Epoch: 996 reconstruction error: 1.071787
# Epoch: 997 reconstruction error: 1.071543
# Epoch: 998 reconstruction error: 1.071658
# Epoch: 999 reconstruction error: 1.071589

# %%
# Plot reconstruction errors
pd.Series(err).plot(logy=False)
plt.xlabel("Epoch")
plt.ylabel("Reconstruction Error");

# %%
# Predict ratings for validation set
inputValidation = ratings_validation
inputValidation = inputValidation.astype(np.float32)

finalOutput_validation, reconstructedOutput_validation, _ = \
    rbm.rbm_output(inputValidation)

# %%
# Calculate MSE on validation set
predictionsArray = reconstructedOutput_validation
pred_validation = \
    predictionsArray[ratings_validation.nonzero()].flatten()
actual_validation = \
    ratings_validation[ratings_validation.nonzero()].flatten()

rbm_prediction = mean_squared_error(pred_validation, actual_validation)
print('Mean squared error using RBM prediction:', rbm_prediction)
# Out:
# Mean squared error using RBM prediction: 9.332243405009976
